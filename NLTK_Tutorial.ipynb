# %% [markdown]
# # Natural Language Processing (NLP)

# %% [markdown]
# **Natural Language** : Human Language.
#
# **Processing** : Undestanding and Responding.
#
# ## Components of NLP :
#
# 1. **Natural Language Understanding (NLU)**
#
# 2. **Natural Language Generation (NLG)**
#
# ## Applications of NLP :
#
# 1. Machine Translation
# 2. Speech Recognition
# 3. Sentiment Analysis
# 4. Question Answering
# 5. Automatic Summarization
# 6. Chatbots
# 7. Market Intelligence
# 8. Text Classification
# 9. Character Recognition
# 10. Spell Checking
#
# **Reff:**
# * https://towardsdatascience.com/natural-language-processing-nlp-top-10-applications-to-know-b2c80bd428cb

# %% [markdown]
# # NLTK

# %% [markdown]
# *In python NLTk is the Library used for NLP*

# %%
import nltk

# %%
nltk.download()
# it will download all the corporous and packages
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# ## Tokenization
#
# **the process of breaking the given text**
#
# **In the Python NLTK module, we have different packages related to tokenization**
# * sent_tokenize package
# * word_tokenize package

# %%
from nltk.tokenize import sent_tokenize
para="I am a computer scientist. I am a python developer."
sentences=sent_tokenize(para)
sentences
# Out:
# ['I am a computer scientist.', 'I am a python developer.']

# %%
sentences[1]
# Out:
# 'I am a python developer.'

# %%
from nltk.tokenize import word_tokenize
sent1="I am a python developer"
words=word_tokenize(sent1)
words
# Out:
# ['I', 'am', 'a', 'python', 'developer']

# %%
sent2="I can't play cricket"
words=word_tokenize(sent2)
words
# Out:
# ['I', 'ca', "n't", 'play', 'cricket']

# %% [markdown]
# ## Regular Expression
#
# * **/d** means digit
# * **/s** means white space
# * **/w** means character

# %%
import re

regex=re.compile(r"\w+")

sen="this is my 92456732 and my friend number is 454564765"
regex.search(sen).group()
# Out:
# 'this'

# %%
from nltk.tokenize import regexp_tokenize
sen="I can't complete your work. i won't do that"
# words=word_tokenize(sen)
words=regexp_tokenize(sen,"[\w']+")
words
# Out:
# ['I', "can't", 'complete', 'your', 'work', 'i', "won't", 'do', 'that']

# %% [markdown]
# ## Stop Words
#
# **common words which are not generally convey any meaning**
#
# **used to filter out sentences**

# %%
from nltk.corpus import stopwords
ensw=stopwords.words("english")
ensw
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
from nltk.tokenize import word_tokenize
para="tomorrow is saturday. i am going to office early in the morning"
words=word_tokenize(para)
words
# Out:
# ['tomorrow',
#  'is',
#  'saturday',
#  '.',
#  'i',
#  'am',
#  'going',
#  'to',
#  'office',
#  'early',
#  'in',
#  'the',
#  'morning']

# %%
len(words)
# Out:
# 13

# %%
filter_words=[word for word in words if word not in ensw]
filter_words
# Out:
# ['tomorrow', 'saturday', '.', 'going', 'office', 'early', 'morning']

# %%
len(filter_words)
# Out:
# 7

# %% [markdown]
# ## Stemming
#
# **cut the sentences into base word like *fishes* and *fishing* stem into *fish*.**
#
# **There are various types of Stemmers in Nltk**
# * Porter Stemmer
# * Lancaster Stemmer
# * Regexp Stemmer

# %%
from nltk.stem import PorterStemmer
pstem=PorterStemmer()
pstem.stem("dancing")
# Out:
# 'danc'

# %%
from nltk.stem import LancasterStemmer
lstem=LancasterStemmer()
lstem.stem("dancing")
# Out:
# 'dant'

# %%
from nltk.stem import RegexpStemmer
restem=RegexpStemmer("ing")
restem.stem("dance")
# Out:
# 'dance'

# %% [markdown]
# ## synonyms
#
# * **Linguistic :** Linguistics is the scientific study of language
# * **Synsets** means set of synonyms of words
# * **hypernyms** means set of specific more abstract synonyms (parent class)
# * **hyponyms** means set of specific less abstract synonyms than hypernyms (child class)
#  - e.g : cat hypernyms may be animal, living being etc
#          but cat hyponyms may be tiger cat food and any thing reqarding to it
# * **wordnet** means big dictionery
# * **corpus** means collection of text
# * **n** means noun
# * **v** means verb
# * **a** means adjactive

# %%
from nltk.corpus import wordnet
word="cat"
syn_word=wordnet.synsets(word)
syn_word
# Out:
# [Synset('cat.n.01'),
#  Synset('guy.n.01'),
#  Synset('cat.n.03'),
#  Synset('kat.n.01'),
#  Synset('cat-o'-nine-tails.n.01'),
#  Synset('caterpillar.n.02'),
#  Synset('big_cat.n.01'),
#  Synset('computerized_tomography.n.01'),
#  Synset('cat.v.01'),
#  Synset('vomit.v.01')]

# %%
w=syn_word[0]
w.definition()
w.name()
w.pos()
# Out:
# 'n'

# %%
w.hypernyms()
# Out:
# [Synset('feline.n.01')]

# %%
w.hyponyms()
# Out:
# [Synset('domestic_cat.n.01'), Synset('wildcat.n.03')]

# %%
w.hyponyms()[0].definition()
# Out:
# 'any domesticated member of the genus Felis'

# %%
w.hyponyms()[0].name()
# Out:
# 'domestic_cat.n.01'

# %% [markdown]
# ## Lemmas, Synonyms and Antonyms
# * by using lammas we can generate more Synonyms and Antonyms

# %%
from nltk.corpus import wordnet
word="win"
synset=wordnet.synsets(word)
w=synset[2]
w.lemmas()[0].antonyms()[0].name()
# Out:
# 'lose'

# %% [markdown]
# ## Lemmatization
#
# **We can also extract the base form of words by lemmatization. It basically does this task with the use of a vocabulary and morphological analysis of words, normally aiming to remove inflectional endings only. This kind of base form of any word is called lemma.**
#
# e.g : base word of dancing is dance

# %%
from nltk.stem import WordNetLemmatizer
lz=WordNetLemmatizer()
lz.lemmatize("dancing",pos='v')
# Out:
# 'dance'

# %% [markdown]
# ## List of all Corpora

# %%
import os
import nltk
print(os.listdir(nltk.data.find("corpora")))
# Out:
# ['abc', 'abc.zip', 'alpino', 'alpino.zip', 'biocreative_ppi', 'biocreative_ppi.zip', 'brown', 'brown.zip', 'brown_tei', 'brown_tei.zip', 'cess_cat', 'cess_cat.zip', 'cess_esp', 'cess_esp.zip', 'chat80', 'chat80.zip', 'city_database', 'city_database.zip', 'cmudict', 'cmudict.zip', 'comparative_sentences', 'comparative_sentences.zip', 'comtrans.zip', 'conll2000', 'conll2000.zip', 'conll2002', 'conll2002.zip', 'conll2007.zip', 'crubadan', 'crubadan.zip', 'dependency_treebank', 'dependency_treebank.zip', 'dolch', 'dolch.zip', 'europarl_raw', 'europarl_raw.zip', 'floresta', 'floresta.zip', 'framenet_v15', 'framenet_v15.zip', 'framenet_v17', 'framenet_v17.zip', 'gazetteers', 'gazetteers.zip', 'genesis', 'genesis.zip', 'gutenberg', 'gutenberg.zip', 'ieer', 'ieer.zip', 'inaugural', 'inaugural.zip', 'indian', 'indian.zip', 'jeita.zip', 'kimmo', 'kimmo.zip', 'knbc.zip', 'lin_thesaurus', 'lin_thesaurus.zip', 'machado.zip', 'mac_morpho', 'mac_morpho.zip', 'masc_tagged.zip', 'movie_reviews', 'mov
# ...

# %% [markdown]
# ## list all the documents

# %%
from nltk.corpus import inaugural
print(inaugural.fileids())
# Out:
# ['1789-Washington.txt', '1793-Washington.txt', '1797-Adams.txt', '1801-Jefferson.txt', '1805-Jefferson.txt', '1809-Madison.txt', '1813-Madison.txt', '1817-Monroe.txt', '1821-Monroe.txt', '1825-Adams.txt', '1829-Jackson.txt', '1833-Jackson.txt', '1837-VanBuren.txt', '1841-Harrison.txt', '1845-Polk.txt', '1849-Taylor.txt', '1853-Pierce.txt', '1857-Buchanan.txt', '1861-Lincoln.txt', '1865-Lincoln.txt', '1869-Grant.txt', '1873-Grant.txt', '1877-Hayes.txt', '1881-Garfield.txt', '1885-Cleveland.txt', '1889-Harrison.txt', '1893-Cleveland.txt', '1897-McKinley.txt', '1901-McKinley.txt', '1905-Roosevelt.txt', '1909-Taft.txt', '1913-Wilson.txt', '1917-Wilson.txt', '1921-Harding.txt', '1925-Coolidge.txt', '1929-Hoover.txt', '1933-Roosevelt.txt', '1937-Roosevelt.txt', '1941-Roosevelt.txt', '1945-Roosevelt.txt', '1949-Truman.txt', '1953-Eisenhower.txt', '1957-Eisenhower.txt', '1961-Kennedy.txt', '1965-Johnson.txt', '1969-Nixon.txt', '1973-Nixon.txt', '1977-Carter.txt', '1981-Reagan.txt', '1985-Rea
# ...

# %% [markdown]
# ## TASK

# %% [markdown]
# 1. Using the corpus reader class list all the documents in inaugural corpus
# 2. Find the total number of words in Clinton’s 1993 speech.
# 3. Find the total number of distinct words in the same speech
# 4. Find the average word type length of same speech.

# %%
from nltk.corpus import inaugural
print(inaugural.fileids())
# Out:
# ['1789-Washington.txt', '1793-Washington.txt', '1797-Adams.txt', '1801-Jefferson.txt', '1805-Jefferson.txt', '1809-Madison.txt', '1813-Madison.txt', '1817-Monroe.txt', '1821-Monroe.txt', '1825-Adams.txt', '1829-Jackson.txt', '1833-Jackson.txt', '1837-VanBuren.txt', '1841-Harrison.txt', '1845-Polk.txt', '1849-Taylor.txt', '1853-Pierce.txt', '1857-Buchanan.txt', '1861-Lincoln.txt', '1865-Lincoln.txt', '1869-Grant.txt', '1873-Grant.txt', '1877-Hayes.txt', '1881-Garfield.txt', '1885-Cleveland.txt', '1889-Harrison.txt', '1893-Cleveland.txt', '1897-McKinley.txt', '1901-McKinley.txt', '1905-Roosevelt.txt', '1909-Taft.txt', '1913-Wilson.txt', '1917-Wilson.txt', '1921-Harding.txt', '1925-Coolidge.txt', '1929-Hoover.txt', '1933-Roosevelt.txt', '1937-Roosevelt.txt', '1941-Roosevelt.txt', '1945-Roosevelt.txt', '1949-Truman.txt', '1953-Eisenhower.txt', '1957-Eisenhower.txt', '1961-Kennedy.txt', '1965-Johnson.txt', '1969-Nixon.txt', '1973-Nixon.txt', '1977-Carter.txt', '1981-Reagan.txt', '1985-Rea
# ...

# %%
words=inaugural.words('1993-Clinton.txt')
print(words)
total_number_of_words=len(words)
print()
print(total_number_of_words)
# Out:
# ['My', 'fellow', 'citizens', ',', 'today', 'we', ...]
#
# 1855

# %%
total_distinct_number_of_words=len(set(words))
print()
print(total_distinct_number_of_words)
# Out:
# 643

# %%
set(words)
# Out:
# {'"',
#  "'",
#  ',',
#  '-',
#  '.',
#  '."',
#  '21st',
#  ':',
#  ';',
#  'A',
#  'AIDS',
#  'ALL',
#  'Across',
#  'Almighty',
#  'America',
#  'American',
#  'Americans',
#  'And',
#  'Anyone',
#  'Bush',
#  'But',
#  'Century',
#  'Civil',
#  'Clearly',
#  'Cold',
#  'Communications',
#  'Communism',
#  'Depression',
#  'Each',
#  'Earth',
#  'Enough',
#  'Franklin',
#  'From',
#  'George',
#  'God',
#  'Great',
#  'Gulf',
#  'I',
#  'In',
#  'Instead',
#  'Investment',
#  'It',
#  'Jefferson',
#  'Let',
#  'My',
#  'Not',
#  'Now',
#  'On',
#  'Our',
#  'Persian',
#  'Posterity',
#  'Powerful',
#  'President',
#  'Profound',
#  'Raised',
#  'Revolution',
#  'Rights',
#  'Roosevelt',
#  'Scripture',
#  'Somalia',
#  'THIS',
#  'Technology',
#  'Thank',
#  'The',
#  'Their',
#  'There',
#  'This',
#  'Thomas',
#  'Though',
#  'To',
#  'Today',
#  'Together',
#  'WE',
#  'War',
#  'Washington',
#  'We',
#  'Well',
#  'When',
#  'While',
#  'YOUNG',
#  'Yes',
#  'You',
#  'a',
# ...

# %%
sum_words=0
for word in words:
    sum_words=sum_words+len(word)
print("Sum of Words: "+ str(sum_words))
avg_word_len=sum_words/len(words)
print("average word length in document : "+ str(int(avg_word_len)))
# Out:
# Sum of Words: 7497
# average word length in document : 4

# %% [markdown]
# ## TASK 2:

# %% [markdown]
# 1. Obtain the words from the Clinton’s 1993 speech
# 2. Construct a frequency distribution over the lowercased words in the document
# 3. Write a function that finds the 50 most frequently occurring words in the speech that are not
# stop words.
# 4. Plot the top 50 words
# 5. Find out how many times the words world and america were used in the speech

# %%
from nltk.corpus import inaugural
words=inaugural.words('1993-Clinton.txt')
words
# Out:
# ['My', 'fellow', 'citizens', ',', 'today', 'we', ...]

# %%
lowercase_words=[word for word in words if word.islower()]
lowercase_words
# Out:
# ['fellow',
#  'citizens',
#  'today',
#  'we',
#  'celebrate',
#  'the',
#  'mystery',
#  'of',
#  'renewal',
#  'ceremony',
#  'is',
#  'held',
#  'in',
#  'the',
#  'depth',
#  'of',
#  'winter',
#  'but',
#  'by',
#  'the',
#  'words',
#  'we',
#  'speak',
#  'and',
#  'the',
#  'faces',
#  'we',
#  'show',
#  'the',
#  'world',
#  'we',
#  'force',
#  'the',
#  'spring',
#  'spring',
#  'reborn',
#  'in',
#  'the',
#  'world',
#  's',
#  'oldest',
#  'democracy',
#  'that',
#  'brings',
#  'forth',
#  'the',
#  'vision',
#  'and',
#  'courage',
#  'to',
#  'reinvent',
#  'our',
#  'founders',
#  'boldly',
#  'declared',
#  's',
#  'independence',
#  'to',
#  'the',
#  'world',
#  'and',
#  'our',
#  'purposes',
#  'to',
#  'the',
#  'they',
#  'knew',
#  'that',
#  'to',
#  'endure',
#  'would',
#  'have',
#  'to',
#  'change',
#  'change',
#  'for',
#  'change',
#  'sake',
#  'but',
#  'change',
#  'to',
#  'preserve',
#  's',
#  'ideals',
#  'life',
#  'liberty',
#  'the',
# ...

# %%
from nltk import FreqDist
fd=FreqDist(lowercase_words)
fd
# Out:
# FreqDist({'the': 85, 'and': 63, 'our': 54, 'of': 46, 'to': 45, 'we': 43, 'in': 30, 'is': 28, 'world': 20, 'for': 20, ...})

# %%
from nltk.corpus import stopwords
ensw=stopwords.words("english")
ensw
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
filter_words=[word for word in lowercase_words if word not in ensw]
filter_words
# Out:
# ['fellow',
#  'citizens',
#  'today',
#  'celebrate',
#  'mystery',
#  'renewal',
#  'ceremony',
#  'held',
#  'depth',
#  'winter',
#  'words',
#  'speak',
#  'faces',
#  'show',
#  'world',
#  'force',
#  'spring',
#  'spring',
#  'reborn',
#  'world',
#  'oldest',
#  'democracy',
#  'brings',
#  'forth',
#  'vision',
#  'courage',
#  'reinvent',
#  'founders',
#  'boldly',
#  'declared',
#  'independence',
#  'world',
#  'purposes',
#  'knew',
#  'endure',
#  'would',
#  'change',
#  'change',
#  'change',
#  'sake',
#  'change',
#  'preserve',
#  'ideals',
#  'life',
#  'liberty',
#  'pursuit',
#  'happiness',
#  'march',
#  'music',
#  'time',
#  'mission',
#  'timeless',
#  'generation',
#  'must',
#  'define',
#  'means',
#  'behalf',
#  'nation',
#  'salute',
#  'predecessor',
#  'half',
#  'century',
#  'service',
#  'thank',
#  'millions',
#  'men',
#  'women',
#  'whose',
#  'steadfastness',
#  'sacrifice',
#  'triumphed',
#  'depression',
#  'fascism',
#  'communism',
# ...

# %%
from nltk import FreqDist
fd=FreqDist(filter_words)
fd.most_common(10)
# Out:
# [('world', 20),
#  ('must', 18),
#  ('us', 13),
#  ('people', 12),
#  ('change', 9),
#  ('new', 9),
#  ('today', 7),
#  ('time', 7),
#  ('work', 6),
#  ('fellow', 5)]

# %%
fd.plot(10)

# %%
len_world=fd.pop("world")
len_america=0
print("world : "+ str(len_world))
print("america : "+ str(len_america))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0b75c6cbf89f> in <module>
# ----> 1 len_world=fd.pop("world")
#       2 len_america=0
#       3 print("world : "+ str(len_world))
#       4 print("america : "+ str(len_america))
#
# NameError: name 'fd' is not defined

# %% [markdown]
# ## Task 3 :

# %% [markdown]
# 1. Load the “tweets.cvs” file using pandas (Each line in the file represents a tweet)
# 2. Using nltk, tokenize the tweets.cvs into list of words.
# 3. It is often necessary to normalise the text for any NLP tasks. Unlike normal document or text, the
# extracted tweets from Twitter need not be in a regular form.
#     * Convert all the text in tweets.cvs to lower case letters
#     * Clean tweets.cvs file by removing all the emoticons and slang words
#     * Clean the tweets.cvs file by removing all the stop words
#     * Punctuations are divided into priority. So punctuations like?, ., ! are retained and
#         other like , “”, $, # etc are removed.
#     * Numbers are not important so we will remove numbers from tweets.cvs
#     * Every tweet is followed by a URL that provides a link to the actual tweet. This is not
#       required so remove url’s from tweets.csv file
#     * save this corrected tweets in correctes_tweets.csv
#
# 4. Apply Potter Stemmer.
# 5. find and print the top 20 most frequent (unique words)
# from the tweets.cvs Plot the frequency distribution using pyPlot.

# %%
import pandas as pd
df=pd.read_csv("tweets.csv",encoding="unicode_escape",header=None)
df
# Out:
#        0                                                  1
# 0      1  Watch your favourite Pakistani Dramas, Movies ...
# 1      2  @ZahirPost Apne number pr maujood arzi taur pe...
# 2      3       @zeeni_U We are connected with you via DM :)
# 3      4  @zeeni_U Please DM us your usage details, we w...
# 4      5  @zeeni_U Hi, Please let us know if you need an...
# ..   ...                                                ...
# 351  352  @AliHussain6188 @Spogmai_SR We are glad that y...
# 352  353         @Mushi_Sidd Thank you for your kind words.
# 353  354  @burhankgan42093 We are glad that you like our...
# 354  355  @PervezI05130532 Thank you for your appriciati...
# 355  356  @AfridiFan_MUFC Hi, It depends on your usage &...
#
# [356 rows x 2 columns]

# %%
list_tweets=list(df[1])
list_tweets
# Out:
# ['Watch your favourite Pakistani Dramas, Movies and TV Series using Zong\x92s Fastest Mobile Internet. For Details:\x85 https://t.co/qcXKmimMJc',
#  '@ZahirPost Apne number pr maujood arzi taur per band services kay baare mein janne or de-activate kerne kay liye "L\x85 https://t.co/KvkTTZRnxX',
#  '@zeeni_U We are connected with you via DM :)',
#  '@zeeni_U Please DM us your usage details, we will suggest you best bundle according to your usage.',
#  '@zeeni_U Hi, Please let us know if you need any assistance regarding Zong Services.',
#  'All your favourite packages of SMS, Internet and Voice are now at one place\xa0#Zong4G\xa0Online Shop!\x85 https://t.co/vXK8zGGpY2',
#  '@tzash Your required details have been shared kindly check your message box and let us know if still any assistance is required.',
#  '@tzash Hi, We definitely want to get this addressed for you, please DM your Zong number for further facilitation.',
# ...

# %%
from nltk.tokenize import word_tokenize
words=word_tokenize("".join(list_tweets))
words
# Out:
# ['Watch',
#  'your',
#  'favourite',
#  'Pakistani',
#  'Dramas',
#  ',',
#  'Movies',
#  'and',
#  'TV',
#  'Series',
#  'using',
#  'Zong\x92s',
#  'Fastest',
#  'Mobile',
#  'Internet',
#  '.',
#  'For',
#  'Details',
#  ':',
#  'https',
#  ':',
#  '//t.co/qcXKmimMJc',
#  '@',
#  'ZahirPost',
#  'Apne',
#  'number',
#  'pr',
#  'maujood',
#  'arzi',
#  'taur',
#  'per',
#  'band',
#  'services',
#  'kay',
#  'baare',
#  'mein',
#  'janne',
#  'or',
#  'de-activate',
#  'kerne',
#  'kay',
#  'liye',
#  '``',
#  'L',
#  'https',
#  ':',
#  '//t.co/KvkTTZRnxX',
#  '@',
#  'zeeni_U',
#  'We',
#  'are',
#  'connected',
#  'with',
#  'you',
#  'via',
#  'DM',
#  ':',
#  ')',
#  '@',
#  'zeeni_U',
#  'Please',
#  'DM',
#  'us',
#  'your',
#  'usage',
#  'details',
#  ',',
#  'we',
#  'will',
#  'suggest',
#  'you',
#  'best',
#  'bundle',
#  'according',
#  'to',
#  'your',
#  'usage',
#  '.',
#  '@',
#  'zeeni_U',
#  'Hi',
#  ',',
#  'Please',
#  'let',
#  'us',
#  'know',
#  'if',
# ...

# %%
len(words)
# Out:
# 6800

# %%
import re
from nltk.corpus import stopwords
ensw=stopwords.words("english")

def filter_url(word):
    regrex_pattern =re.compile(r"((http|https)\:\/\/)?[a-zA-Z0-9\.\/\?\:@\-_=#]+\.([a-zA-Z]){2,6}([a-zA-Z0-9\.\&\/\?\:@\-_=#])*")
    return regrex_pattern.sub(r'',word)


def filter_punc(word):
    regrex_pattern = re.compile(r"[#$%&'()\*\+-/:;<=>@[\]^_`{|}~]")
    return regrex_pattern.sub(r'',word)

def filter_digit(word):
    regrex_pattern =re.compile(r"[\d]+")
    return regrex_pattern.sub(r'',word)


def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

def filter_stopword(word):
    if word not in ensw:
        return(word)
    else:
        return ""
 

def filterout(tweets):
    
    filter_tweet=[]
    for sent in tweets:
        sentence=[]
        for word in sent.split(" "):
            sentence.append((filter_digit(filter_stopword(deEmojify(filter_punc(filter_url(word.lower())))))))
        filter_tweet.append(" ".join(sentence))
    
    return filter_tweet

list_corrected_tweets=filterout(list_tweets)
list_corrected_tweets
# Out:
# ['watch  favourite pakistani dramas movies  tv series using zong\x92s fastest mobile internet  details\x85 ',
#  'zahirpost apne number pr maujood arzi taur per band services kay baare mein janne  deactivate kerne kay liye "l\x85 ',
#  'zeeniu   connected   via dm ',
#  'zeeniu please dm us  usage details   suggest  best bundle according   usage',
#  'zeeniu hi please let us know   need  assistance regarding zong services',
#  '  favourite packages  sms internet  voice    one place\xa0zongg\xa0online shop!\x85 ',
#  'tzash  required details   shared kindly check  message box  let us know  still  assistance  required',
#  'tzash hi  definitely want  get  addressed   please dm  zong number   facilitation',
#  'aamirabbas  cannot use gsm sim   zong mbb device',
#  'aamirabbas hi aamir    use zong mbb sim   zong mbb device   mapped   device',
#  'chotayabbu hi abid give us  chance  look   concern kindly share  contact number  message box   assistance',
# ...

# %%
df=pd.DataFrame({"Correct Tweets": list_corrected_tweets})
df.to_csv("corrected_tweets.csv")

# %%
from nltk.tokenize import word_tokenize
filter_words=word_tokenize("".join(list_corrected_tweets))
filter_words
# Out:
# ['watch',
#  'favourite',
#  'pakistani',
#  'dramas',
#  'movies',
#  'tv',
#  'series',
#  'using',
#  'zong\x92s',
#  'fastest',
#  'mobile',
#  'internet',
#  'details',
#  'zahirpost',
#  'apne',
#  'number',
#  'pr',
#  'maujood',
#  'arzi',
#  'taur',
#  'per',
#  'band',
#  'services',
#  'kay',
#  'baare',
#  'mein',
#  'janne',
#  'deactivate',
#  'kerne',
#  'kay',
#  'liye',
#  '``',
#  'l',
#  'zeeniu',
#  'connected',
#  'via',
#  'dm',
#  'zeeniu',
#  'please',
#  'dm',
#  'us',
#  'usage',
#  'details',
#  'suggest',
#  'best',
#  'bundle',
#  'according',
#  'usagezeeniu',
#  'hi',
#  'please',
#  'let',
#  'us',
#  'know',
#  'need',
#  'assistance',
#  'regarding',
#  'zong',
#  'services',
#  'favourite',
#  'packages',
#  'sms',
#  'internet',
#  'voice',
#  'one',
#  'place',
#  'zongg',
#  'online',
#  'shop',
#  '!',
#  'tzash',
#  'required',
#  'details',
#  'shared',
#  'kindly',
#  'check',
#  'message',
#  'box',
#  'let',
#  'us',
#  'know',
#  'still',
# ...

# %%
from nltk.stem import PorterStemmer
stem_words=[]
pstem=PorterStemmer()
for word in filter_words:
    stem_words.append(pstem.stem(word))
stem_words
# Out:
# ['watch',
#  'favourit',
#  'pakistani',
#  'drama',
#  'movi',
#  'tv',
#  'seri',
#  'use',
#  'zong\x92',
#  'fastest',
#  'mobil',
#  'internet',
#  'detail',
#  'zahirpost',
#  'apn',
#  'number',
#  'pr',
#  'maujood',
#  'arzi',
#  'taur',
#  'per',
#  'band',
#  'servic',
#  'kay',
#  'baar',
#  'mein',
#  'jann',
#  'deactiv',
#  'kern',
#  'kay',
#  'liy',
#  '``',
#  'l',
#  'zeeniu',
#  'connect',
#  'via',
#  'dm',
#  'zeeniu',
#  'pleas',
#  'dm',
#  'us',
#  'usag',
#  'detail',
#  'suggest',
#  'best',
#  'bundl',
#  'accord',
#  'usagezeeniu',
#  'hi',
#  'pleas',
#  'let',
#  'us',
#  'know',
#  'need',
#  'assist',
#  'regard',
#  'zong',
#  'servic',
#  'favourit',
#  'packag',
#  'sm',
#  'internet',
#  'voic',
#  'one',
#  'place',
#  'zongg',
#  'onlin',
#  'shop',
#  '!',
#  'tzash',
#  'requir',
#  'detail',
#  'share',
#  'kindli',
#  'check',
#  'messag',
#  'box',
#  'let',
#  'us',
#  'know',
#  'still',
#  'assist',
#  'requiredtzash',
#  'hi',
# ...

# %%
from nltk import FreqDist

fd=FreqDist(stem_words)
fd.most_common(20)
# Out:
# [('hi', 177),
#  ('zong', 127),
#  ('pleas', 114),
#  ('dm', 98),
#  ('number', 94),
#  ('kindli', 67),
#  ('detail', 52),
#  ('us', 49),
#  ('connect', 46),
#  ('check', 44),
#  ('thank', 43),
#  ('share', 41),
#  ('ap', 38),
#  ('messag', 34),
#  ('via', 33),
#  ('kay', 31),
#  ('offer', 31),
#  ('get', 30),
#  ('link', 29),
#  ('box', 27)]

# %%
fd.plot(20)

# %% [markdown]
# ## Project Gender Classificaion

# %%
from nltk.corpus import names
names.fileids()
# Out:
# ['female.txt', 'male.txt']

# %%
names.words('male.txt')
# Out:
# ['Aamir',
#  'Aaron',
#  'Abbey',
#  'Abbie',
#  'Abbot',
#  'Abbott',
#  'Abby',
#  'Abdel',
#  'Abdul',
#  'Abdulkarim',
#  'Abdullah',
#  'Abe',
#  'Abel',
#  'Abelard',
#  'Abner',
#  'Abraham',
#  'Abram',
#  'Ace',
#  'Adair',
#  'Adam',
#  'Adams',
#  'Addie',
#  'Adger',
#  'Aditya',
#  'Adlai',
#  'Adnan',
#  'Adolf',
#  'Adolfo',
#  'Adolph',
#  'Adolphe',
#  'Adolpho',
#  'Adolphus',
#  'Adrian',
#  'Adrick',
#  'Adrien',
#  'Agamemnon',
#  'Aguinaldo',
#  'Aguste',
#  'Agustin',
#  'Aharon',
#  'Ahmad',
#  'Ahmed',
#  'Ahmet',
#  'Ajai',
#  'Ajay',
#  'Al',
#  'Alaa',
#  'Alain',
#  'Alan',
#  'Alasdair',
#  'Alastair',
#  'Albatros',
#  'Albert',
#  'Alberto',
#  'Albrecht',
#  'Alden',
#  'Aldis',
#  'Aldo',
#  'Aldric',
#  'Aldrich',
#  'Aldus',
#  'Aldwin',
#  'Alec',
#  'Aleck',
#  'Alejandro',
#  'Aleks',
#  'Aleksandrs',
#  'Alessandro',
#  'Alex',
#  'Alexander',
#  'Alexei',
#  'Alexis',
#  'Alf',
#  'Alfie',
#  'Alfonse',
#  'Alfonso',
#  'Alfonzo',
# ...

# %%
from nltk.corpus import names
from nltk.classify import NaiveBayesClassifier

def gender(word):
    return {"last_letter ": word[-1]}

lab_names=[(name,"male") for name in names.words("male.txt")]+[(name,"female") for name in names.words("female.txt")]
train_data=[(gender(n),g)for (n,g) in lab_names]
model=NaiveBayesClassifier.train(train_data)

# %%
model.classify(gender("Kiran"))
# Out:
# 'male'

# %% [markdown]
# ## References and Credits

# %% [markdown]
# * https://www.youtube.com/watch?v=IqPWZL5f-7g&list=PLcTXcpndN-Sl9eYrKM6jtcOTgC52EJnqH
# * https://www.nltk.org/book/
# * https://www.nltk.org/book/ch01
# * https://www.tutorialspoint.com/artificial_intelligence_with_python/artificial_intelligence_with_python_natural_language_processing.htm
# * https://www.tutorialspoint.com/python_text_processing/python_tokenization.htm
# * https://guides.github.com/features/mastering-markdown/
